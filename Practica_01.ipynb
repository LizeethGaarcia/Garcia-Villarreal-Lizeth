# %% [markdown]
# # Práctica_01
# ##Preparación de Datos

# %%
import pandas as pd
import numpy as np
import json

# %%
df = pd.read_csv("C:\\Users\\Lizee\\Desktop\\MineriaDatos\\Practica_01\\Unclean_data1.txt")

# %%
df.head()
# Out:
#                                   movie_title  num_critic_for_reviews  \
# 0                                    Avatar?ÿ                     723
# 1  Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                   Spectre?ÿ                     602
# 3                     The Dark Knight Rises?ÿ                     813
# 4                               John Carter?ÿ                     462
#
#    duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 0     178.0                      10                     855
# 1       NaN                     563                    1000
# 2     148.0                      20                     161
# 3       NaN                   22000                   23000
# 4     132.0                   "475"                     530
#
#    ACTOR_1_facebook_likes      gross  num_voted_users  \
# 0                    1000  760505847         886204.0
# 1                   40000  309404152         471220.0
# ...

# %%
df.tail()
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# 12                           Quantum of Solace?ÿ                     403
# 13  Pirates of the Caribbean: Dead Man's Chest?ÿ                     313
#
#     duration DIRECTOR_facebook_likes  actor_3_facebook_likes  \
# 9      153.0                     282                   10000
# 10     183.0                     NaN                    2000
# 11     169.0                     NaN                     903
# 12     106.0                     395                     393
# 13     151.0                     563                    1000
#
#     ACTOR_1_facebook_likes      gross  num_voted_users  \
# 9                    25000  301956980         321795.0
# ...

# %%
df.columns
# Out:
# Index(['movie_title', 'num_critic_for_reviews', 'duration',
#        'DIRECTOR_facebook_likes', 'actor_3_facebook_likes',
#        'ACTOR_1_facebook_likes', 'gross', 'num_voted_users',
#        'Cast_Total_facebook_likes', 'facenumber_in_poster',
#        'num_user_for_reviews', 'budget', 'title_year',
#        'ACTOR_2_facebook_likes', 'imdb_score', 'title_year.1'],
#       dtype='object')

# %%
df.dtypes
# Out:
# movie_title                   object
# num_critic_for_reviews         int64
# duration                     float64
# DIRECTOR_facebook_likes       object
# actor_3_facebook_likes         int64
# ACTOR_1_facebook_likes         int64
# gross                          int64
# num_voted_users              float64
# Cast_Total_facebook_likes    float64
# facenumber_in_poster         float64
# num_user_for_reviews           int64
# budget                         int64
# title_year                     int64
# ACTOR_2_facebook_likes       float64
# imdb_score                   float64
# title_year.1                 float64
# dtype: object

# %%
df['movie_title'].dtype
# Out:
# dtype('O')

# %%
df.isnull()
# Out:
#     movie_title  num_critic_for_reviews  duration  DIRECTOR_facebook_likes  \
# 0         False                   False     False                    False
# 1         False                   False      True                    False
# 2         False                   False     False                    False
# 3         False                   False      True                    False
# 4         False                   False     False                    False
# 5         False                   False     False                    False
# 6         False                   False      True                    False
# 7         False                   False     False                    False
# 8         False                   False     False                    False
# 9         False                   False     False                    False
# 10        False                   False     False                     True
# ...

# %%
df.isnull().any()
# Out:
# movie_title                  False
# num_critic_for_reviews       False
# duration                      True
# DIRECTOR_facebook_likes       True
# actor_3_facebook_likes       False
# ACTOR_1_facebook_likes       False
# gross                        False
# num_voted_users               True
# Cast_Total_facebook_likes     True
# facenumber_in_poster          True
# num_user_for_reviews         False
# budget                       False
# title_year                   False
# ACTOR_2_facebook_likes        True
# imdb_score                   False
# title_year.1                  True
# dtype: bool

# %%
df.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# DIRECTOR_facebook_likes      2
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# Cast_Total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 7
# dtype: int64

# %%
#Se cambiará el nombre de las siguientes columnas por otros más cortos.

df.rename(columns = {'DIRECTOR_facebook_likes':'dirc_fb_likes','actor_3_facebook_likes':'actor3_fb_likes','ACTOR_1_facebook_likes':'actor1_fb_likes','Cast_Total_facebook_likes':'cast_total_fb_likes','ACTOR_2_facebook_likes':'actor2_fb_likes'})
# Out:
#                                      movie_title  num_critic_for_reviews  \
# 0                                       Avatar?ÿ                     723
# 1     Pirates of the Caribbean: At World's End?ÿ                     302
# 2                                      Spectre?ÿ                     602
# 3                        The Dark Knight Rises?ÿ                     813
# 4                                  John Carter?ÿ                     462
# 5                                 Spider-Man 3?ÿ                     392
# 6                                      Tangled?ÿ                     324
# 7                      Avengers: Age of Ultron?ÿ                     635
# 8                      Avengers: Age of Ultron?ÿ                     635
# 9       Harry Potter and the Half-Blood Prince?ÿ                     375
# 10          Batman v Superman: Dawn of Justice?ÿ                     673
# 11                            Superman Returns?ÿ                     434
# ...

# %%
df.movie_title.unique()
# Out:
# array(['Avatar?ÿ', "Pirates of the Caribbean: At World's End?ÿ",
#        'Spectre?ÿ', 'The Dark Knight Rises?ÿ', 'John Carter?ÿ',
#        'Spider-Man 3?ÿ', 'Tangled?ÿ', 'Avengers: Age of Ultron?ÿ',
#        'Harry Potter and the Half-Blood Prince?ÿ',
#        'Batman v Superman: Dawn of Justice?ÿ', 'Superman Returns?ÿ',
#        'Quantum of Solace?ÿ',
#        "Pirates of the Caribbean: Dead Man's Chest?ÿ"], dtype=object)

# %%
df.num_critic_for_reviews.unique()
# Out:
# array([723, 302, 602, 813, 462, 392, 324, 635, 375, 673, 434, 403, 313],
#       dtype=int64)

# %%
df.duration.unique()
# Out:
# array([178.,  nan, 148., 132., 156., 141., 153., 183., 169., 106., 151.])

# %%
df.DIRECTOR_facebook_likes.unique()
# Out:
# array(['10', '563', '20', '22000', '"475"', '23', '15', '282', nan, '395'],
#       dtype=object)

# %%
agrupacion_1 = df[df['movie_title']=='Avengers: Age of Ultron?ÿ']

agrupacion_1.to_csv('Solo_agrupacion1.csv', index=False)

# %%
agrupacion_2 = df[df['DIRECTOR_facebook_likes']=='10']

agrupacion_2.to_csv('Solo_agrupacion2.csv', index=False)

# %% [markdown]
# ###Pregunta de interés: ¿Para que me puede servir estas agrupaciones para la práctica siguiente?
# ###R: Puede servir para observar cuáles datos comparten un mismo valor de la columna que deseemos comparar.

# %%
df.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     3
# DIRECTOR_facebook_likes      2
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              1
# Cast_Total_facebook_likes    2
# facenumber_in_poster         5
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       1
# imdb_score                   0
# title_year.1                 7
# dtype: int64

# %% [markdown]
# ###Pregunta de interés: Importancia del analisis previo de los datos antes de iniciar las modificaciones.
# ###R: Debemos verificar qué tipo de dato es y qué técnica se va a utilizar, porque si modificamos, los resultados no serán los más acertados.

# %%
df_0 = df.fillna(0)

# %%
df_0.isnull().sum()
# Out:
# movie_title                  0
# num_critic_for_reviews       0
# duration                     0
# DIRECTOR_facebook_likes      0
# actor_3_facebook_likes       0
# ACTOR_1_facebook_likes       0
# gross                        0
# num_voted_users              0
# Cast_Total_facebook_likes    0
# facenumber_in_poster         0
# num_user_for_reviews         0
# budget                       0
# title_year                   0
# ACTOR_2_facebook_likes       0
# imdb_score                   0
# title_year.1                 0
# dtype: int64
